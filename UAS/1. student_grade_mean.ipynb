# %%
students_grade=[
    {
        'student_number':101,
        'name':'Andri',
        'subject':['Programming Basic','Web Programming'],
        'grade':[80,90]
    },
    {
        'student_number':102,
        'name':'Budi',
        'subject':['Programming Basic','Web Programming'],
        'grade':[90,80]
    },
    {
        'student_number':103,
        'name':'Cika',
        'subject':['Programming Basic','Web Programming'],
        'grade':[100,80]
    },
    {
        'student_number':104,
        'name':'Dedi',
        'subject':['Programming Basic','Web Programming'],
        'grade':[100,90]
    },
    {
        'student_number':105,
        'name':'Eka',
        'subject':['Programming Basic','Web Programming'],
        'grade':[50,90]
    },
    {
        'student_number':106,
        'name':'Feri',
        'subject':['Programming Basic','Web Programming'],
        'grade':[40,60]
    },
    {
        'student_number':107,
        'name':'Galih',
        'subject':['Programming Basic','Web Programming'],
        'grade':[70,95]
    },
    {
        'student_number':108,
        'name':'Huda',
        'subject':['Programming Basic','Web Programming'],
        'grade':[70,85]
    },
    {
        'student_number':109,
        'name':'Intan',
        'subject':['Programming Basic','Web Programming'],
        'grade':[60,90]
    },
]

def determinate_grade(students_grade):
    for student in students_grade:
        student_number = student['student_number']
        name = student['name']
        subject = student['subject']
        grade = student['grade']
        for i in range(len(subject)):
            if grade[i] > 80:
                print("Student Number :",student_number)
                print("Name :",name)
                print('Subject :',subject[i])
                print('Grade :',grade[i])
                print(' ')

determinate_grade(students_grade)
# Out:
# Student Number : 101
# Name : Andri
# Subject : Web Programming
# Grade : 90
#
# Student Number : 102
# Name : Budi
# Subject : Programming Basic
# Grade : 90
#
# Student Number : 103
# Name : Cika
# Subject : Programming Basic
# Grade : 100
#
# Student Number : 104
# Name : Dedi
# Subject : Programming Basic
# Grade : 100
#
# Student Number : 104
# Name : Dedi
# Subject : Web Programming
# Grade : 90
#
# Student Number : 105
# Name : Eka
# Subject : Web Programming
# Grade : 90
#
# Student Number : 107
# Name : Galih
# Subject : Web Programming
# Grade : 95
#
# Student Number : 108
# Name : Huda
# Subject : Web Programming
# Grade : 85
#
# Student Number : 109
# Name : Intan
# Subject : Web Programming
# Grade : 90
